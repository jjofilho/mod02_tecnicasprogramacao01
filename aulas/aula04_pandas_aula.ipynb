# %% [markdown]
# # Pandas - Aula 1

# %% [markdown]
# ## Instalação, Documentação e estrutura

# %% [markdown]
# A biblioteca pandas é fundamental na área de Data Science com python. Construída a partir do numpy, o módulo pandas possibilita a estruturação e manipulação de dados de maneira simples e eficiente. Vamos trabalhar com tabelas/planilhas.

# %% [markdown]
# O nome **PANDAS** é devirado de _panel data_ (dados em painel), um termo da econometria para conjuntos de dados estruturados. Ele tem desempenho com recursos flexíveis de manipulação de planilhas e de bancos de dados
#
# O pandas permite trabalhar com diferentes tipos de dados como por exemplo, dados _tabulares_ (planilhas de excel) ou uma tabela de SQL
#
# Vantagens:
#
# - Facilidade de aprender e de ultilizar a biblioteca
# - Comunidade crescente ativa
# - Documentação rica
# - Permite uma visualizaçaõ e dados
# - Trabalha muito bem com series temporais
# - Traz muitas informações estatísticas
# - Uso de operações
# - etc..

# %% [markdown]
# https://pandas.pydata.org/
#
# https://pandas.pydata.org/docs/
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html
#
# dica: procurar por "pandas cheat sheet" na internet
#
# https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf

# %% [markdown]
# `conda install -c anaconda pandas`
#
# ou
#
# `pip install pandas`

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Estrutura de dados**

# %% [markdown]
# ![Screenshot 2024-01-15 at 08.40.33.png](<attachment:Screenshot 2024-01-15 at 08.40.33.png>)

# %% [markdown]
# ![Screenshot 2024-01-15 at 08.40.59.png](<attachment:Screenshot 2024-01-15 at 08.40.59.png>)

# %% [markdown]
# ## Séries

# %% [markdown]
# Uma série é uma lista simples (ou uma coluna) de dados do mesmo tipo associado a uma lista de labels, chamadas de index. As Series são basicamente as colunas das tabelas e armazenam suas informações com o numpy array. Neste caso, porém, esse array possuirá um índice associado, permitindo o acesso aos conteúdos dessa estrutura por ele.

# %%
# Criar uma série a partir de uma lista

# %%
# criar uma série a partir de um array

# %%
# criar uma série com index

# %%
# Em milhões

# %% [markdown]
# Alguém pode não saber que representamos uma população em milhões de habitantes. A Série pode ter um `nome`, para melhor documentar o propósito da Série:

# %% [markdown]
# Series são muito similares a numpy arrays:

# %% [markdown]
# Elas são construidas por numpy arrays na realidade

# %% [markdown]
# E eles _se parecem_ com listas simples de Python ou Numpy Arrays. Mas na verdade eles são mais parecidos com os `dict`s do Python.
#
# Uma série possui um `índice`, que é semelhante ao índice automático atribuído às listas do Python:

# %% [markdown]
# Porém, ao contrário de lista, podemos definir o index

# %% [markdown]
# Compare os dados com a [seguinte tabela](https://docs.google.com/spreadsheets/d/1IlorV2-Oh9Da1JAZ7weVw86PQrQydSMp-ydVMH135iI/edit?usp=sharing):
#
# <img width="350" src="https://user-images.githubusercontent.com/872296/38149656-b5ce9816-3431-11e8-88e4-195756e25355.png" />
#
# Podemos dizer que Series são dicionários ordenados, e podemos criar elas a partir do próprio dicionário do Python

# %% [markdown]
# ------------
# ## Indexação
#
# A indexação funciona de forma semelhante às listas e dicionários, você usa o **índice** do elemento que procura:

# %% [markdown]
# Posições numéricas também podem ser utilizadas, com o atributo `iloc`:

# %% [markdown]
# Selecionando múltiplos elementos de uma vez

# %% [markdown]
# _(O resultado é uma outra Serie)_

# %% [markdown]
# Fatiar também funciona, mas **importante**, no Pandas, o limite superior também está incluído:

# %% [markdown]
# --------------
#
# ## Seleção condicional (matrizes booleanas)
#
# As mesmas técnicas de array booleano que vimos aplicadas a arrays numpy podem ser usadas para Pandas `Series`:

# %% [markdown]
# --------------------------------
#
# ## Operações e métodos
#
# As séries também suportam operações vetorizadas e funções de agregação como Numpy:

# %% [markdown]
# -------------------------
#
# ## Matrizes booleanas
#
# (Funciona da mesma forma que numpy)

# %% [markdown]
# --------------------------
#
# ## Modificando a Serie

# %% [markdown]
# ## Exercicio:
#
# 1. Crie uma Serie com elementos A, B, C e com os indexes primeiro, segundo, terceiro
# 2. Agora mostre o primeiro elemento da Serie anterior
# 3. Baseado na Serie X = pd.Series([1,2,3,4,5],
#               index=['first','second','third','forth','fifth'])
#               **Transforme** em float
# 4. Mude a ordem da mesma Serie utilizada no Exercicio 3
# 5. Organize os valores da Serie X = pd.Series([4,2,5,1,3],
#               index=['forth','second','fifth','first','third'])
# 6. Add 5 para todos os elementos da Serie X = pd.Series([1,2,3,4,5])
# 7. Crie uma máscara para mostrar somente elementos negativos X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])
# 8. Colete todos os elementos negativos X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])
